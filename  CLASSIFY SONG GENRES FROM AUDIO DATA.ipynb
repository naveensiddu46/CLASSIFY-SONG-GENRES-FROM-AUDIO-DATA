# %% [markdown]
# # Load the dataset

# %%
 import pandas as pd

# %%
# Read in track metadata with genre labels
tracks = pd.read_csv('fma-rock-vs-hiphop.csv')

# %%
tracks.head()
# Out:
#    track_id  bit_rate  comments        composer         date_created  \
# 0       135    256000         1             NaN  2008-11-26 01:43:26
# 1       136    256000         1             NaN  2008-11-26 01:43:35
# 2       151    192000         0             NaN  2008-11-26 01:44:55
# 3       152    192000         0             NaN  2008-11-26 01:44:58
# 4       153    256000         0  Arc and Sender  2008-11-26 01:45:00
#
#          date_recorded  duration  favorites genre_top    genres  \
# 0  2008-11-26 00:00:00       837          0      Rock  [45, 58]
# 1  2008-11-26 00:00:00       509          0      Rock  [45, 58]
# 2                  NaN       192          0      Rock      [25]
# 3                  NaN       193          0      Rock      [25]
# 4  2008-11-26 00:00:00       405          5      Rock      [26]
#
#               ...             information interest  language_code  \
# 0             ...                     NaN     2484             en
# 1             ...                     NaN     1948             en
# 2             ...                     NaN      701             en
# 3             ...                     NaN      637             en
# 4             ...                     NaN      354             en
#
#                                              license listens  lyricist number  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1832       NaN      0
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...    1498       NaN      0
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...     148       NaN      4
# 3  Attribution-NonCommercial-ShareAlike 3.0 Inter...      98       NaN     11
# 4  Attribution-NonCommercial-NoDerivatives (aka M...     424       NaN      2
#
#    publisher tags                       title
# 0        NaN   []                Father's Day
# 1        NaN   []  Peel Back The Mountain Sky
# 2        NaN   []                 Untitled 04
# 3        NaN   []                 Untitled 11
# 4        NaN   []          Hundred-Year Flood
#
# [5 rows x 21 columns]

# %%
# Read in track metrics with the features
echonest_metrics = pd.read_json('echonest-metrics.json', precise_float = True)

# %%
echonest_metrics.head()
# Out:
#       track_id  acousticness  danceability    energy  instrumentalness  \
# 0            2      0.416675      0.675894  0.634476          0.010628
# 1            3      0.374408      0.528643  0.817461          0.001851
# 10         145      0.235506      0.438672  0.487752          0.716122
# 100        341      0.977282      0.468808  0.134975          0.687700
# 1000      3457      0.081256      0.897197  0.367886          0.104474
#
#       liveness  speechiness    tempo   valence
# 0     0.177647     0.159310  165.922  0.576661
# 1     0.105880     0.461818  126.957  0.269240
# 10    0.070359     0.047298  120.790  0.650452
# 100   0.105381     0.073124  119.646  0.430707
# 1000  0.085845     0.041271  100.744  0.749293

# %%
# Merge the track_id and genre_top columns of tracks and echonest_metrics on track_id values
echo_tracks = pd.merge(left = tracks[['track_id', 'genre_top']], right=echonest_metrics, on='track_id')

echo_tracks.head()
# Out:
#    track_id genre_top  acousticness  danceability    energy  instrumentalness  \
# 0       153      Rock      0.988306      0.255661  0.979774          0.973006
# 1       154      Rock      0.970135      0.352946  0.023852          0.957113
# 2       155      Rock      0.981657      0.142249  0.912122          0.967294
# 3       169      Rock      0.989141      0.225978  0.722835          0.263076
# 4       170      Rock      0.886660      0.298518  0.744333          0.920950
#
#    liveness  speechiness   tempo   valence
# 0  0.121342     0.051740  90.241  0.034018
# 1  0.113261     0.032177  53.758  0.035632
# 2  0.363510     0.087527  91.912  0.034325
# 3  0.092371     0.053406  94.322  0.028347
# 4  0.139587     0.088781  97.880  0.073548

# %%
# Inspect the resultant dataframe
echo_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4802 entries, 0 to 4801
# Data columns (total 10 columns):
# track_id            4802 non-null int64
# genre_top           4802 non-null object
# acousticness        4802 non-null float64
# danceability        4802 non-null float64
# energy              4802 non-null float64
# instrumentalness    4802 non-null float64
# liveness            4802 non-null float64
# speechiness         4802 non-null float64
# tempo               4802 non-null float64
# valence             4802 non-null float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 412.7+ KB

# %%
display(echo_tracks["genre_top"].value_counts())
# Out:
# Rock       3892
# Hip-Hop     910
# Name: genre_top, dtype: int64

# %% [markdown]
# # Pairwise relationships between continuous variables

# %%
# Create a correlation matrix
corr_metrics = echo_tracks.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col0 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col2 {
#             background-color:  #d2d2e7;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col3 {
#             background-color:  #b5c4df;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col4 {
#             background-color:  #f5eef6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col5 {
#             background-color:  #e9e5f1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col6 {
#             background-color:  #d1d2e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col7 {
#             background-color:  #e1dfed;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row0_col8 {
#             background-color:  #dedcec;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col1 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col2 {
#             background-color:  #e0dded;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col3 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col4 {
#             background-color:  #97b7d7;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col5 {
#             background-color:  #f3edf5;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col6 {
#             background-color:  #b8c6e0;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col7 {
#             background-color:  #e1dfed;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row1_col8 {
#             background-color:  #e2dfee;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col0 {
#             background-color:  #bdc8e1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col1 {
#             background-color:  #d0d1e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col2 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col3 {
#             background-color:  #fbf3f9;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col4 {
#             background-color:  #f3edf5;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col6 {
#             background-color:  #80aed2;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col7 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row2_col8 {
#             background-color:  #529bc7;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col0 {
#             background-color:  #a7bddb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col1 {
#             background-color:  #f5eff6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col2 {
#             background-color:  #fef6fa;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col3 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col4 {
#             background-color:  #c4cbe3;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col5 {
#             background-color:  #dcdaeb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col6 {
#             background-color:  #dedcec;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col7 {
#             background-color:  #adc1dd;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row3_col8 {
#             background-color:  #d9d8ea;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col0 {
#             background-color:  #f4eef6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col1 {
#             background-color:  #97b7d7;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col2 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col3 {
#             background-color:  #d2d3e7;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col4 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col5 {
#             background-color:  #fdf5fa;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col6 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col7 {
#             background-color:  #d9d8ea;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row4_col8 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col0 {
#             background-color:  #bdc8e1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col1 {
#             background-color:  #ced0e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col2 {
#             background-color:  #ede8f3;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col3 {
#             background-color:  #bdc8e1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col4 {
#             background-color:  #dbdaeb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col5 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col6 {
#             background-color:  #c0c9e2;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col7 {
#             background-color:  #dcdaeb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row5_col8 {
#             background-color:  #e8e4f0;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col0 {
#             background-color:  #d0d1e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col1 {
#             background-color:  #b8c6e0;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col2 {
#             background-color:  #93b5d6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col3 {
#             background-color:  #eae6f1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col4 {
#             background-color:  #fff7fb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col5 {
#             background-color:  #eae6f1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col6 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col7 {
#             background-color:  #dbdaeb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row6_col8 {
#             background-color:  #bfc9e1;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col0 {
#             background-color:  #d0d1e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col1 {
#             background-color:  #d0d1e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col2 {
#             background-color:  #fef6fa;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col3 {
#             background-color:  #a7bddb;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col4 {
#             background-color:  #c5cce3;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col5 {
#             background-color:  #f0eaf4;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col6 {
#             background-color:  #c8cde4;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col7 {
#             background-color:  #023858;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row7_col8 {
#             background-color:  #d6d6e9;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row8_col0 {
#             background-color:  #c6cce3;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row8_col1 {
#             background-color:  #cdd0e5;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row8_col2 {
#             background-color:  #4c99c5;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row8_col3 {
#             background-color:  #d1d2e6;
#         }    #T_34d37d0c_08f7_11e9_baa6_ace2d3cfd7f0row8_col4 {
#             bac

# %%
echo_tracks.drop(["track_id"], axis=1).describe()
# Out:
#        acousticness  danceability       energy  instrumentalness     liveness  \
# count  4.802000e+03   4802.000000  4802.000000       4802.000000  4802.000000
# mean   4.870600e-01      0.436556     0.625126          0.604096     0.187997
# std    3.681396e-01      0.183502     0.244051          0.376487     0.150562
# min    9.491000e-07      0.051307     0.000279          0.000000     0.025297
# 25%    8.351236e-02      0.296047     0.450757          0.164972     0.104052
# 50%    5.156888e-01      0.419447     0.648374          0.808752     0.123080
# 75%    8.555765e-01      0.565339     0.837016          0.915472     0.215151
# max    9.957965e-01      0.961871     0.999768          0.993134     0.971392
#
#        speechiness        tempo      valence
# count  4802.000000  4802.000000  4802.000000
# mean      0.104877   126.687944     0.453413
# std       0.145934    34.002473     0.266632
# min       0.023234    29.093000     0.014392
# 25%       0.036897    98.000750     0.224617
# 50%       0.049594   124.625500     0.446240
# 75%       0.088290   151.450000     0.666914
# max       0.966177   250.059000     0.983649

# %% [markdown]
# # Normalizing the feature data

# %%
# Define our features 
features = echo_tracks.drop(["genre_top","track_id"], axis=1)
features.head()
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  \
# 0      0.988306      0.255661  0.979774          0.973006  0.121342
# 1      0.970135      0.352946  0.023852          0.957113  0.113261
# 2      0.981657      0.142249  0.912122          0.967294  0.363510
# 3      0.989141      0.225978  0.722835          0.263076  0.092371
# 4      0.886660      0.298518  0.744333          0.920950  0.139587
#
#    speechiness   tempo   valence
# 0     0.051740  90.241  0.034018
# 1     0.032177  53.758  0.035632
# 2     0.087527  91.912  0.034325
# 3     0.053406  94.322  0.028347
# 4     0.088781  97.880  0.073548

# %%
# Define our labels
labels = echo_tracks["genre_top"]
labels.head()
# Out:
# 0    Rock
# 1    Rock
# 2    Rock
# 3    Rock
# 4    Rock
# Name: genre_top, dtype: object

# %%
# Import the StandardScaler
from sklearn.preprocessing import StandardScaler

# Scale the features and set the values to a new variable
scaler = StandardScaler()
scaled_train_features = scaler.fit_transform(features)
pd.DataFrame(scaled_train_features).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.361706 -0.985896  1.453323  0.979975 -0.442757 -0.364157 -1.072003
# 1  1.312342 -0.455681 -2.463985  0.937757 -0.496436 -0.498224 -2.145066
# 2  1.343645 -1.604002  1.176091  0.964802  1.165836 -0.118903 -1.022854
# 3  1.363976 -1.147674  0.400404 -0.905888 -0.635199 -0.352735 -0.951969
# 4  1.085570 -0.752319  0.488500  0.841695 -0.321565 -0.110309 -0.847319
#
#           7
# 0 -1.573102
# 1 -1.567050
# 2 -1.571949
# 3 -1.594372
# 4 -1.424831

# %% [markdown]
# #  Principal Component Analysis on our scaled data

# %%
# Import our plotting module, and PCA class
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Get our explained variance ratios from PCA using all features
pca = PCA()
pca.fit(scaled_train_features)
exp_variance = pca.explained_variance_ratio_

# plot the explained variance using a barplot
fig, ax = plt.subplots()
ax.bar(range(pca.n_components_), exp_variance)
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# # Further visualization of PCA

# %%
# Import numpy
import numpy as np

# Calculate the cumulative explained variance
cum_exp_variance = np.cumsum(exp_variance)

# Plot the cumulative explained variance and draw a dashed line at 0.90.
fig, ax = plt.subplots()
ax.plot(cum_exp_variance)
ax.axhline(y=0.9, linestyle='--')
n_components = 6

# Perform PCA with the chosen number of components and project data onto components
pca = PCA(n_components=n_components, random_state=0)
pca.fit(scaled_train_features)
projection = pca.transform(scaled_train_features)

# %% [markdown]
# # Train a decision tree to classify genre

# %%
# Import train_test_split function and Decision tree classifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Split our data
train_features, test_features, train_labels, test_labels = train_test_split(projection, labels, random_state=10)

# Train our decision tree
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)

# Predict the labels for the test data
pred_labels_tree = tree.predict(test_features)

# %% [markdown]
# # Compare our decision tree to a logistic regression

# %%
# Import LogisticRegression
from sklearn.linear_model import LogisticRegression

# Train our logisitic regression and predict labels for the test set
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Create the classification report for both models
from sklearn.metrics import classification_report
class_rep_tree = classification_report(test_labels, pred_labels_tree)
class_rep_log = classification_report(test_labels, pred_labels_logit)

print("Decision Tree: \n", class_rep_tree)
print("Logistic Regression: \n", class_rep_log)
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.63      0.62      0.63       229
#        Rock       0.91      0.91      0.91       972
#
# avg / total       0.86      0.86      0.86      1201
#
# Logistic Regression:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.75      0.51      0.61       229
#        Rock       0.89      0.96      0.93       972
#
# avg / total       0.87      0.87      0.86      1201

# %% [markdown]
# # Balance our data for greater performance

# %%
# Subset only the hip-hop tracks, and then only the rock tracks
hop_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Hip-Hop']
rock_only = echo_tracks.loc[echo_tracks['genre_top'] == 'Rock']

# sample the rocks songs to be the same number as there are hip-hop songs
rock_only = rock_only.sample(n=hop_only.shape[0], random_state=0)

# concatenate the dataframes hop_only and rock_only
rock_hop_bal = pd.concat([hop_only, rock_only], ignore_index=True)

# Redefine our train, test sets
features, labels = rock_hop_bal.drop(['genre_top', 'track_id'], axis=1), rock_hop_bal['genre_top']
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, random_state=10)

# %% [markdown]
# # Confirm whether balancing our dataset improves our model bias

# %%
# Train our decision tree on the balanced data
tree = DecisionTreeClassifier(random_state=10)
tree.fit(train_features, train_labels)
pred_labels_tree = tree.predict(test_features)

# Train our logistic regression on the balanced data
logreg = LogisticRegression(random_state=10)
logreg.fit(train_features, train_labels)
pred_labels_logit = logreg.predict(test_features)

# Compare the models
print("Decision Tree: \n", classification_report(test_labels, pred_labels_tree))
print("Logistic Regression: \n", classification_report(test_labels, pred_labels_logit))
# Out:
# Decision Tree:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.84      0.87      0.85       225
#        Rock       0.87      0.83      0.85       230
#
# avg / total       0.85      0.85      0.85       455
#
# Logistic Regression:
#               precision    recall  f1-score   support
#
#     Hip-Hop       0.84      0.84      0.84       225
#        Rock       0.84      0.84      0.84       230
#
# avg / total       0.84      0.84      0.84       455

# %% [markdown]
# # Using cross-validation to evaluate our models

# %%
from sklearn.model_selection import KFold, cross_val_score

# Set up our K-fold cross-validation
kf = KFold(10, random_state=10)

tree = DecisionTreeClassifier(random_state=10)
logreg = LogisticRegression(random_state=10)

# Train our models using KFold cv
tree_score = cross_val_score(tree, features, labels, cv=kf)
logit_score = cross_val_score(logreg, features, labels, cv=kf)

# Print the mean of each array of scores
print("Decision Tree:", np.mean(tree_score), "Logistic Regression:", np.mean(logit_score))
# Out:
# Decision Tree: 0.8148351648351649 Logistic Regression: 0.7972527472527473
